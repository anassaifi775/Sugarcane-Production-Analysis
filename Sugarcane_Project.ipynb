# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df= pd.read_csv("List of Countries by Sugarcane Production.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %% [markdown]
# ## Data Cleaning

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace('.','')
df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace('.','').str.replace(',','.')
df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace('.','')
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].str.replace('.','').str.replace(',','.')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.rename(columns={'Production (Tons)':'Production(Tons)'},inplace=True)
df.rename(columns={'Production per Person (Kg)':'Production_per_Person(Kg)'},inplace=True)
df.rename(columns={'Acreage (Hectare)':'Acreage(Hectare)'},inplace=True)
df.rename(columns={'Yield (Kg / Hectare)':'Yield(Kg/Hectare)'},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                  3668.531         10226205           75167.5
# 1                    260721          4950000           70393.5
# 2                     88287          1675215           73459.1
# 3                  1264.303          1336575           65442.2
# 4                    324219          1130820             57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df[df['Acreage(Hectare)'].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production(Tons) Production_per_Person(Kg)  \
# 99          99  Djibouti    Africa               53                        51
#
#    Acreage(Hectare) Yield(Kg/Hectare)
# 99              NaN               NaN

# %%
df.dropna(inplace= True)
df.reset_index()
# Out:
#      index  Unnamed: 0    Country      Continent Production(Tons)  \
# 0        0           0     Brazil  South America        768678382
# 1        1           1      India           Asia        348448000
# 2        2           2      China           Asia        123059739
# 3        3           3   Thailand           Asia         87468496
# 4        4           4   Pakistan           Asia         65450704
# ..     ...         ...        ...            ...              ...
# 97      97          97      Spain         Europe              394
# 98      98          98    Lebanon           Asia               97
# 99     100         100  Singapore           Asia               50
# 100    101         101      Samoa        Oceania               12
# 101    102         102      Syria           Asia                1
#
#     Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                    3668.531         10226205           75167.5
# 1                      260721          4950000           70393.5
# 2                       88287          1675215           73459.1
# 3                    1264.303          1336575           65442.2
# 4                      324219          1130820             57879
# ..                        ...              ...               ...
# 97                          8                9           43596.5
# 98                         16                3           28386.4
# 99                          9                2                25
# 100                         6                1           11949.8
# 101                         0                0           83034.2
#
# [102 rows x 8 columns]

# %%
df[df['Acreage(Hectare)'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Country, Continent, Production(Tons), Production_per_Person(Kg), Acreage(Hectare), Yield(Kg/Hectare)]
# Index: []

# %%
df.drop('Unnamed: 0',axis=1, inplace= True)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_Person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df['Production(Tons)'] = df['Production(Tons)'].astype(float)
df['Production_per_Person(Kg)'] = df['Production_per_Person(Kg)'].astype(float)
df['Acreage(Hectare)'] = df['Acreage(Hectare)'].astype(float)
df['Yield(Kg/Hectare)'] = df['Yield(Kg/Hectare)'].astype(float)

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# ## How many countries produce sugarcane from each continent?

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df['Continent'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## Distribution of the columns

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df['Production(Tons)'])
plt.subplot(2,2,2)
sns.distplot(df['Production_per_Person(Kg)'])
plt.subplot(2,2,3)
sns.distplot(df['Acreage(Hectare)'])
plt.subplot(2,2,4)
sns.distplot(df['Yield(Kg/Hectare)'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\2467860319.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production(Tons)'])
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\2467860319.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production_per_Person(Kg)'])
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\2467860319.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Acreage(Hectare)'])
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\2467860319.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Yield(Kg/Hectare)'])
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Density'>

# %% [markdown]
# ## Checking the outliers

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df['Production(Tons)'])
plt.subplot(2,2,2)
sns.boxplot(df['Production_per_Person(Kg)'])
plt.subplot(2,2,3)
sns.boxplot(df['Acreage(Hectare)'])
plt.subplot(2,2,4)
sns.boxplot(df['Yield(Kg/Hectare)'])
# Out:
# <Axes: ylabel='Yield(Kg/Hectare)'>

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# ## Bivariate Analysis

# %%
df.head(10)
# Out:
#                     Country      Continent  Production(Tons)  \
# 0                    Brazil  South America       768678382.0
# 1                     India           Asia       348448000.0
# 2                     China           Asia       123059739.0
# 3                  Thailand           Asia        87468496.0
# 4                  Pakistan           Asia        65450704.0
# 5                    Mexico  North America        56446821.0
# 6                  Colombia  South America        36951213.0
# 7                 Australia        Oceania        34403004.0
# 8                 Guatemala  North America        33533403.0
# 9  United States of America  North America        29926210.0
#
#    Production_per_Person(Kg)  Acreage(Hectare)  Yield(Kg/Hectare)
# 0                   3668.531        10226205.0            75167.5
# 1                 260721.000         4950000.0            70393.5
# 2                  88287.000         1675215.0            73459.1
# 3                   1264.303         1336575.0            65442.2
# 4                 324219.000         1130820.0            57879.0
# 5                 452524.000          781054.0             7227.0
# 6                 740075.000          416626.0            88691.5
# 7                   1373.406          447204.0            76929.1
# 8                   1938.114           25985.0           129049.3
# 9                  91304.000           37053.0            80766.0

# %% [markdown]
# ### Which country produces maximum sugarcane?

# %%
df_new = df[['Country','Production(Tons)']].set_index('Country')

# %%
df_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
df_new['Production(Tons)_percent'] = df_new['Production(Tons)']*100/df_new['Production(Tons)'].sum()
df_new['Production(Tons)_percent'].round(3)
# Out:
# Country
# Brazil       40.727
# India        18.462
# China         6.520
# Thailand      4.634
# Pakistan      3.468
#               ...
# Spain         0.000
# Lebanon       0.000
# Singapore     0.000
# Samoa         0.000
# Syria         0.000
# Name: Production(Tons)_percent, Length: 102, dtype: float64

# %%
df_new['Production(Tons)_percent'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df_new['Production(Tons)_percent'].head(10).plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df_new['Production(Tons)_percent'].head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
ax=sns.barplot(data= df.head(10), x= 'Country', y= 'Production(Tons)')

# %% [markdown]
# ### Which country has highest land?

# %%
df_new = df[['Country','Acreage(Hectare)']].set_index('Country')

# %%
df_new
# Out:
#            Acreage(Hectare)
# Country
# Brazil           10226205.0
# India             4950000.0
# China             1675215.0
# Thailand          1336575.0
# Pakistan          1130820.0
# ...                     ...
# Spain                   9.0
# Lebanon                 3.0
# Singapore               2.0
# Samoa                   1.0
# Syria                   0.0
#
# [102 rows x 1 columns]

# %%
df_acr= df.sort_values('Acreage(Hectare)', ascending = False)
ax=sns.barplot(data= df_acr.head(10), x= 'Country', y= 'Acreage(Hectare)',palette='dark')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\282792087.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data= df_acr.head(10), x= 'Country', y= 'Acreage(Hectare)',palette='dark')
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\282792087.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# [Text(0, 0, 'Brazil'),
#  Text(1, 0, 'India'),
#  Text(2, 0, 'China'),
#  Text(3, 0, 'Thailand'),
#  Text(4, 0, 'Pakistan'),
#  Text(5, 0, 'Mexico'),
#  Text(6, 0, 'Indonesia'),
#  Text(7, 0, 'Australia'),
#  Text(8, 0, 'Cuba'),
#  Text(9, 0, 'Colombia')]

# %% [markdown]
# ### Which country has highest yield per hectare?

# %%
df_yield= df.sort_values('Yield(Kg/Hectare)', ascending = False)
ax=sns.barplot(data= df_yield.head(10), x= 'Country', y= 'Yield(Kg/Hectare)',palette='muted')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\1772380300.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data= df_yield.head(10), x= 'Country', y= 'Yield(Kg/Hectare)',palette='muted')
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\1772380300.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# [Text(0, 0, 'Guatemala'),
#  Text(1, 0, 'Senegal'),
#  Text(2, 0, 'Egypt'),
#  Text(3, 0, 'Peru'),
#  Text(4, 0, 'Malawi'),
#  Text(5, 0, 'Chad'),
#  Text(6, 0, 'Zambia'),
#  Text(7, 0, 'Burkina Faso'),
#  Text(8, 0, 'Swaziland'),
#  Text(9, 0, 'Nicaragua')]

# %% [markdown]
# ### Which country has the highest production?

# %%
df_prod= df.sort_values('Production_per_Person(Kg)', ascending = False)
ax=sns.barplot(data= df_prod.head(10), x= 'Country', y= 'Production_per_Person(Kg)',palette='Set2')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\3547077580.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data= df_prod.head(10), x= 'Country', y= 'Production_per_Person(Kg)',palette='Set2')
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\3547077580.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# [Text(0, 0, 'Paraguay'),
#  Text(1, 0, 'Colombia'),
#  Text(2, 0, 'Trinidad and Tobago'),
#  Text(3, 0, 'Panama'),
#  Text(4, 0, 'Jamaica'),
#  Text(5, 0, 'Ecuador'),
#  Text(6, 0, 'Argentina'),
#  Text(7, 0, 'Dominican Republic'),
#  Text(8, 0, 'Mexico'),
#  Text(9, 0, 'Pakistan')]

# %% [markdown]
# ## Correlation

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
numeric_df.corr()
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_Person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield(Kg/Hectare)                  0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.997550           0.132812
# Production_per_Person(Kg)          0.012557           0.017999
# Acreage(Hectare)                   1.000000           0.113433
# Yield(Kg/Hectare)                  0.113433           1.000000

# %%
sns.heatmap(numeric_df.corr(), annot= True,cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# ### Do countries with highest land produce more sugarcane?

# %%
sns.scatterplot(data=df, x='Acreage(Hectare)', y='Production(Tons)')
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ### Do countries which yield more sugarcane per hectare produces more sugarcane in total?

# %%
sns.scatterplot(data=df, x='Yield(Kg/Hectare)', y='Production(Tons)')
# Out:
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ## Analysis for Continent

# %%
df_continent= df.groupby('Continent').sum()

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)
# Continent
# Africa                 2142107.5
# Asia                   1171871.4
# Europe                  131870.9
# North America          1082602.4
# Oceania                 162419.1
# South America           677192.7

# %% [markdown]
# ### Which continent produces maximum sugarcane

# %%
df_continent['Production(Tons)'].sort_values(ascending=False)
# Out:
# Continent
# South America    865588126.0
# Asia             721930425.0
# North America    173995947.0
# Africa            89681472.0
# Oceania           36177574.0
# Europe                5823.0
# Name: Production(Tons), dtype: float64

# %%
df_continent['Production(Tons)'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ### Do number of countries in a Continent effects production of sugarcane?

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df_continent['number_of_countries']= df.groupby('Continent').count()['Country']

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)  number_of_countries
# Continent
# Africa                 2142107.5                   38
# Asia                   1171871.4                   25
# Europe                  131870.9                    2
# North America          1082602.4                   22
# Oceania                 162419.1                    4
# South America           677192.7                   11

# %%
continent_names= df_continent.index.to_list()
sns.lineplot(data= df_continent.head(10), x= 'number_of_countries', y= 'Production(Tons)',palette='Set2')
plt.xticks(df_continent['number_of_countries'],continent_names,rotation=90)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_31520\2437259289.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data= df_continent.head(10), x= 'number_of_countries', y= 'Production(Tons)',palette='Set2')

# %% [markdown]
# ### Do continent with highest land produces more sugarcane?

# %%
sns.lineplot(data = df_continent,x = "Acreage(Hectare)", y= "Production(Tons)" )
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ### Production distribution by continent?

# %%
df_continent['Production(Tons)'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Production(Tons)'>
